# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('score.csv')

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
sns.scatterplot(x=df['Hours'],y=df['Scores'],color='red')
plt.title('Hours VS Scores ')
plt.xlabel('Hours of study')
plt.ylabel('Hours of Scores')
# Out:
# Text(0, 0.5, 'Hours of Scores')

# %%
def cost(y_predict,y):
    return (sum(y_predict-y)**2)/df.shape[0]

# %%
def mean_squared_error(y_predicted,y,x):
    cost = np.sum((y_predicted-y)**2) / len(x)
    return cost

# %%
def gradint_Desecent(a_0,a_1,x,y):
    it=5
    learing_rate= 0.01
    n = float(len(x))
    for i in range(it):
        y_predicted = (np.dot(a_1,x)) + a_1
        cost_current=mean_squared_error(y_predicted,y,x)
        costs.append(cost_current)
        slope_1=(2/n)*sum(y_predicted-y)
        step_size_1=slope_1*learing_rate
        a_0=a_0-step_size_1
        weights.append(a_0)
        slope_2 = (2/n) * sum(x * (y_predicted-y))
        step_size_2= slope_2*learing_rate
        a_1=a_1-step_size_2
        print(f"Iteration {i+1}: Cost {cost_current}, Weight \
        {a_1}, Bias {a_0}")
    
    return a_0,a_1

# %%
a_0,a_1=gradint_Desecent(a_0=0.01,a_1= 0.1,x=df['Hours'].values,y=df['Scores'].values)
# Out:
# Iteration 1: Cost 3190.595452, Weight         6.3846136, Bias 1.0275760000000003
# Iteration 2: Cost 270.77334208141843, Weight         8.1124801247296, Bias 1.2894900607360003
# Iteration 3: Cost 53.149530736213926, Weight         8.587532835572658, Bias 1.3436454505385131
# Iteration 4: Cost 37.54755876507438, Weight         8.718141927681003, Bias 1.3406805023892567
# Iteration 5: Cost 36.60140103357386, Weight         8.754051069028904, Bias 1.322011117004893

# %%
plt.figure(figsize=(20,10))
Y_pred = a_0+np.dot(a_1,df['Hours'].values)
plt.scatter(x=df['Hours'],y=df['Scores'])
plt.plot([min(df['Hours']), max(df['Hours'])], [min(Y_pred), max(Y_pred)], color='blue',markerfacecolor='red',
markersize=10,linestyle='dashed')
